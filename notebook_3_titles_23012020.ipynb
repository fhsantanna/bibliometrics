# %% [markdown]
# # Title analyses

# %%
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords
import seaborn as sns

# %%
df = pd.read_csv("table_1_eligible.csv", index_col=[0]) #it reads table derived from medline file

# %%
df.head(5)
# Out:
#                                              Journal  \
# 0  International journal of systematic and evolut...
# 1  International journal of systematic and evolut...
# 4  International journal of systematic and evolut...
# 5  International journal of systematic and evolut...
# 6  International journal of systematic and evolut...
#
#                                                Title  \
# 0  Leucothrix arctica sp. nov., isolated from Arc...
# 1  Hyphobacterium indicum sp. nov., isolated from...
# 4  Sphingopyxis lindanitolerans sp. nov. strain W...
# 5  Mesosutterella multiformis gen. nov., sp. nov....
# 6  Acinetobacter sichuanensis sp. nov., recovered...
#
#                                              Authors  Year  \
# 0  ['Baek Kiwoon' 'Choi Ahyoung' 'Lee Yung Mi' 'L...  2018
# 1  ['Ruan Chu-Jin' 'Zheng Xiao-Wei' 'Wang Jian' '...  2018
# 4  ['Kaminski Michal A' 'Sobczak Adam' 'Spolnik G...  2018
# 5  ['Sakamoto Mitsuo' 'Ikeyama Nao' 'Kunihiro Tad...  2018
# ...

# %%
titles = df[["Journal", "Title", "Year"]].copy()

# %%
titles.head(5)
# Out:
#                                              Journal  \
# 0  International journal of systematic and evolut...
# 1  International journal of systematic and evolut...
# 4  International journal of systematic and evolut...
# 5  International journal of systematic and evolut...
# 6  International journal of systematic and evolut...
#
#                                                Title  Year
# 0  Leucothrix arctica sp. nov., isolated from Arc...  2018
# 1  Hyphobacterium indicum sp. nov., isolated from...  2018
# 4  Sphingopyxis lindanitolerans sp. nov. strain W...  2018
# 5  Mesosutterella multiformis gen. nov., sp. nov....  2018
# 6  Acinetobacter sichuanensis sp. nov., recovered...  2018

# %% [markdown]
# # Species correction

# %%
#Some species presented wrong names in the database
def correct_species(text): 
    substitutions = {"A. oryzae":"Acidovorax oryzae",
                     "A. tolypomycina":"Amycolatopsis tolypomycina",
                     "A. vancoresmycina":"Amycolatopsis vancoresmycina",
                     "Acinetobactercelticus": "Acinetobacter celticus",
                     "Aliisedimentitalea scapharcae": "Alisedimentitalea scapharcae",
                     "Anoxybacillusgeothermalis":"Anoxybacillus geothermalis",
                     "B. ultramafica":"Burkholderia ultramafica",
                     "Bacillusurumqiensis":"Bacillus urumqiensis",
                     "Corynebacteriumpollutisoli":"Corynebacterium pollutisoli",
                     "D. flagellata":"Dyella flagellata",
                     "D. nitratireducens":"Dyella nitratireducens",
                     "Dethosulfovibrio acidaminovorans":"Dethiosulfovibrio acidaminovorans",
                     "Dethosulfovibrio marinus":"Dethiosulfovibrio marinus",
                     "Dickeyafangzhongdai":"Dickeya fangzhongdai",
                     "Friedmaniella sagamiharensis":"Friedmanniella sagamiharensis",
                     "G. acetica":"Gibbsiella acetica",
                     "G. kuznetsovii":"Giesbergeria kuznetsovii",
                     "H. enhydrae":"Helicobacter enhydrae",
                     "K. gansuensis":"Kitasatospora gansuensis",
                     "K. nipponensis":"Kitasatospora nipponensis",
                     "K. paranensis":"Kitasatospora paranensis",
                     "K. terrestris":"Kitasatospora terrestris",
                     "Kibdelosporangiumrhizosphaerae":"Kibdelosporangium rhizosphaerae",
                     "Kordiaulvae":"Kordia ulvae",
                     "L. chiayiensis":"Lactobacillus chiayiensis",
                     "Lactobacilus nuruki":"Lactobacillus nuruki",
                     "M. aquiplantarum":"Marinomonas aquiplantarum",
                     "M. foliarum":"Marinomonas foliarum",
                     "M. parjimensis":"Maricaulis parjimensis",
                     "M. posidonica":"Marinomonas posidonica",
                     "M. rhizomae":"Marinomonas rhizomae",
                     "M. salignorans":"Maricaulis salignorans",
                     "M. washingtonensis":"Maricaulis washingtonensis",
                     "Massiliapinisoli":"Massilia pinisoli",
                     "Mesorhizobiumerdmanii":"Mesorhizobium erdmanii",
                     "Mesorhizobiumjaponicum":"Mesorhizobium japonicum",
                     "Mesorhizobiumjarvisii":"Mesorhizobium jarvisii",
                     "Mucilaginibacterpsychrotolerans":"Mucilaginibacter psychrotolerans",
                     "N. exhalans":"Nocardiopsis exhalans",
                     "N. umidischolae":"Nocardiopsis umidischolae",
                     "Niabellapedocola":"Niabella pedocola",
                     "Niastellahibisci":"Niastella hibisci",
                     "Nocardiajiangsuensis":"Nocardia jiangsuensis",
                     "Nocardiopsissediminis":"Nocardiopsis sediminis",
                     "Novosphingobiumflavum":"Novosphingobium flavum",
                     "O. chuto":"Orientia chuto",
                     "Octadecabacterponticola":"Octadecabacter ponticola",
                     "Paenibacillusliaoningensis":"Paenibacillus liaoningensis",
                     "Paenibacillusoryzae":"Paenibacillus oryzae",
                     "Paraburkholderiapallidirosea":"Paraburkholderia pallidirosea",
                     "Paracoccusacridae":"Paracoccus acridae",
                     "Pedobacterlycopersici":"Pedobacter lycopersici",
                     "Pedobacterpsychrotolerans":"Pedobacter psychrotolerans",
                     "Plantactinosporasoyae":"Plantactinospora soyae",
                     "Primorskyibacteraestuariivivens":"Primorskyibacter aestuariivivens",
                     "Psedoduganella eburnea":"Pseudoduganella eburnea",
                     "Pseudohongiellanitratireducens":"Pseudohongiella nitratireducens",
                     "Sphingobacteriumsoli":"Sphingobacterium soli",
                     "Sphingomonaszeicaulis":"Sphingomonas zeicaulis",
                     "Streptococcusdentiloxodontae":"Streptococcus dentiloxodontae",
                     "Streptococcusmarmotae":"Streptococcus marmotae",
                     "Streptococcuspantholopis":"Streptococcus pantholopis",
                     "Pontibacter locisalis Sy30T":"Pontibacter locisalis",
                     "Thalassotaleaprofundi":"Thalassotalea profundi",
                     "Themoanaerobacterium calidifontis":"Thermoanaerobacterium calidifontis",
                     "Tropicimonasarenosa":"Tropicimonas arenosa",
                     "X. vietnamensis":"Xenorhabdus vietnamensis",
                     "Enterococcus Xinjiangensis":"Enterococcus xinjiangensis",
                     "Clostridium geopurificans strain MJ1":"Clostridium geopurificans",
                     "Planktotalealamellibrachiae":"Planktotalea lamellibrachiae",
                     "Emticiciafontis":"Emticicia fontis"}
    for i,j in substitutions.items():
        text = text.replace(i,j)
    return(text)

titles["Title"] = titles["Title"].apply(correct_species)

# %% [markdown]
# # Species extraction

# %%
import re

titles["species"] = titles["Title"].str.findall('[A-Z]\w+ [a-z]\w+ (?:sp\. nov|sp\.nov)|[A-Z]\w+ (?:sp\. nov|sp\.nov)|[A-Z]\w+ [a-z]\w+ (?:gen\. nov|gen\.nov)|[A-Z]. \w+ (?:sp\. nov|sp\.nov)') #tenta primeiro duas palavras antes do padrão, depois uma

titles
titles.to_csv("species.txt")

# %%
titles
titles["species"].to_csv("lista_species.csv")

# %%
#the code below permits verifying species names that are repeated
from  itertools import chain
from collections import Counter

species = pd.Series(list(chain.from_iterable(titles["species"])))
freq_species = species.value_counts()
freq_species.to_csv("freq_species.csv")

# %%
freq_species.head(30)
# Out:
# Burkholderia humi sp. nov             2
# Flavobacterium aquaticum sp. nov      2
# Mycobacterium sherrisii sp. nov       2
# Aeromonas sharmana sp. nov            2
# Deinococcus soli sp. nov              2
# Aeromonas aquariorum sp. nov          2
# Jeotgalibacillus soli sp. nov         2
# Glaciimonas alpina sp. nov            2
# Novosphingobium aquaticum sp. nov     2
# Nocardioides soli sp. nov             2
# Chitinophaga terrae sp. nov           2
# Sphingomonas ginsengisoli sp. nov     2
# Lysobacter humi sp. nov               2
# Cronobacter turicensis sp. nov        2
# Borrelia carolinensis sp. nov         2
# Sphingomonas aeria sp. nov            2
# Streptomyces mangrovi sp. nov         2
# Mycobacterium shigaense sp. nov       2
# Pseudomonas furukawaii sp. nov        2
# Agromyces mangrovi sp. nov            2
# Paenibacillus beijingensis sp. nov    2
# Cronobacter muytjensii sp. nov        2
# Cronobacter dublinensis sp. nov       2
# ...

# %% [markdown]
# # Genera count - corrected table

# %%
freq_species_ncorr_df = pd.read_csv("freq_species.csv", header=None)
freq_species_ncorr_df.columns = ["species", "freq"]
freq_species_ncorr_df.head(3)
# Out:
#                             species  freq
# 0         Burkholderia humi sp. nov     2
# 1  Flavobacterium aquaticum sp. nov     2
# 2   Mycobacterium sherrisii sp. nov     2

# %%
freq_species_ncorr_df.info() #number of names (10800)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10799 entries, 0 to 10798
# Data columns (total 2 columns):
# species    10799 non-null object
# freq       10799 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 168.8+ KB

# %%
freq_species_ncorr_df["Genus"] = freq_species_ncorr_df["species"].str.split(" ").apply(lambda x: x[0])
freq_species_ncorr_df.head(3)
# Out:
#                             species  freq           Genus
# 0         Burkholderia humi sp. nov     2    Burkholderia
# 1  Flavobacterium aquaticum sp. nov     2  Flavobacterium
# 2   Mycobacterium sherrisii sp. nov     2   Mycobacterium

# %%
freq_species_ncorr_df["Genus"].value_counts().to_csv("genera_counts.csv") #total number of genera (2440), some species are repeated
freq_species_ncorr_df["Genus"].value_counts()
# Out:
# Streptomyces         274
# Bacillus             252
# Paenibacillus        220
# Flavobacterium       180
# Lactobacillus        145
# Pseudomonas          137
# Sphingomonas         116
# Mycobacterium        109
# Chryseobacterium     103
# Nocardioides          99
# Vibrio                94
# Halomonas             93
# Rhizobium             92
# Burkholderia          83
# Microbacterium        81
# Pedobacter            81
# Nocardia              79
# Micromonospora        67
# Clostridium           66
# Amycolatopsis         66
# Streptococcus         64
# Corynebacterium       63
# Hymenobacter          62
# Deinococcus           61
# Shewanella            60
# Mucilaginibacter      54
# Lysobacter            50
# Acinetobacter         48
# Paracoccus            48
# Arthrobacter          47
#                     ...
# Ruthenibacterium       1
# Thiofractor            1
# Spongiivirga           1
# Sulfurivirga           1
# Flindersiella          1
# Aquincola              1
# ...

# %%
freq_species_ncorr_df["Genus"].value_counts().head(10).plot(kind="bar")

# %%
freq_species_ncorr_df["Genus"].value_counts().head(10).to_csv("generos.txt")

# %%
top_genera = pd.DataFrame(freq_species_ncorr_df["Genus"].value_counts().head(10)).reset_index()
top_genera
# Out:
#               index  Genus
# 0      Streptomyces    274
# 1          Bacillus    252
# 2     Paenibacillus    220
# 3    Flavobacterium    180
# 4     Lactobacillus    145
# 5       Pseudomonas    137
# 6      Sphingomonas    116
# 7     Mycobacterium    109
# 8  Chryseobacterium    103
# 9      Nocardioides     99

# %%
top_genera.columns = ["Genus", "Frequency"]

# %%
top_genera
# Out:
#               Genus  Frequency
# 0      Streptomyces        274
# 1          Bacillus        252
# 2     Paenibacillus        220
# 3    Flavobacterium        180
# 4     Lactobacillus        145
# 5       Pseudomonas        137
# 6      Sphingomonas        116
# 7     Mycobacterium        109
# 8  Chryseobacterium        103
# 9      Nocardioides         99

# %% [markdown]
# # Figure 5 - Genus

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib.pyplot import savefig
from matplotlib import rcParams

fig, ax = plt.subplots(figsize=(9,5))
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)
ax.xaxis.set_tick_params(width=1.5, labelsize=14)
ax.yaxis.set_tick_params(width=1.5, labelsize=14)
ax.set_yticklabels(top_genera["Genus"], fontstyle='italic') 
#pal = sns.color_palette("Set1")
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
sns.barplot(x='Frequency', y='Genus', data=top_genera, color="royalblue") #palette=pal
fig.savefig('genus.svg', format='svg', dpi=600)

# %% [markdown]
# # Attributing genera to phyla

# %%
filos = pd.read_csv("bac_lineages_ed3.csv")

# %%
filos.columns = ["phylum", "Genus"]

# %%
filos.head(3)
# Out:
#              phylum            Genus
# 0   Abawacabacteria              NaN
# 1  Abditibacteriota              NaN
# 2  Abditibacteriota  Abditibacterium

# %%
genus_counts = pd.DataFrame(freq_species_ncorr_df["Genus"].value_counts()).reset_index()
genus_counts.columns = ["Genus", "Frequency"]
genus_counts.to_csv("genus_counts.csv")

# %%
filo_genus = pd.merge(genus_counts, filos, on="Genus")

# %%
filo_genus.to_csv("filo_genus.csv")

# %%
filo_counts = pd.DataFrame(filo_genus.groupby("phylum")["Frequency"].sum())

# %%
filo_counts["Frequency"].sum()
# Out:
# 10798

# %%
filo_counts.sort_values(by="Frequency", ascending=False)
# Out:
#                        Frequency
# phylum
# Proteobacteria              4336
# Actinobacteria              2393
# Firmicutes                  1869
# Bacteroidetes               1703
# Deinococcus-Thermus           86
# Spirochaetes                  55
# Acidobacteria                 46
# Verrucomicrobia               45
# Chloroflexi                   34
# Thermotogae                   32
# Aquificae                     26
# Planctomycetes                23
# Fusobacteria                  22
# Cyanobacteria                 21
# Tenericutes                   19
# Synergistetes                 17
# Balneolaeota                  15
# Thermodesulfobacteria         10
# Deferribacteres                8
# Lentisphaerae                  5
# Nitrospirae                    5
# Chlamydiae                     4
# Gemmatimonadetes               4
# Chlorobi                       3
# Calditrichaeota                3
# Rhodothermaeota                3
# Armatimonadetes                3
# ...

# %%
top_filo = filo_counts.sort_values(by="Frequency", ascending=False).head(5).reset_index()
top_filo
# Out:
#                 phylum  Frequency
# 0       Proteobacteria       4336
# 1       Actinobacteria       2393
# 2           Firmicutes       1869
# 3        Bacteroidetes       1703
# 4  Deinococcus-Thermus         86

# %% [markdown]
# # Figure 5 - Phylum

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib.pyplot import savefig
from matplotlib import rcParams

fig, ax = plt.subplots(figsize=(9,2.5))
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)
ax.xaxis.set_tick_params(width=1.5, labelsize=14)
ax.yaxis.set_tick_params(width=1.5, labelsize=14)
pal = sns.color_palette("Set1")
ax.set_yticklabels(top_filo["phylum"], fontstyle='italic') 
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
sns.barplot(x='Frequency', y='phylum', data=top_filo, color="royalblue")
fig.savefig('filo.svg', format='svg', dpi=600)

# %% [markdown]
# # Checking differences between phylum table and the genus table

# %%
merged = genus_counts.merge(filos, on="Genus", indicator=True, how="outer")
sem_filo = merged[merged['_merge'] == 'left_only'] #3 without phylum
sem_filo.to_csv("sem_filo.csv")

# %% [markdown]
# # Wordcloud from titles

# %%
titles
# Out:
#                                                 Journal  \
# 0     International journal of systematic and evolut...
# 1     International journal of systematic and evolut...
# 4     International journal of systematic and evolut...
# 5     International journal of systematic and evolut...
# 6     International journal of systematic and evolut...
# 7     International journal of systematic and evolut...
# 8     International journal of systematic and evolut...
# 9     International journal of systematic and evolut...
# 10    International journal of systematic and evolut...
# 11    International journal of systematic and evolut...
# 12    International journal of systematic and evolut...
# 13    International journal of systematic and evolut...
# 14    International journal of systematic and evolut...
# 15    International journal of systematic and evolut...
# 16    International journal of systematic and evolut...
# 17               Journal of microbiology (Seoul, Korea)
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from collections import Counter

only_titles = titles["Title"]
titles_cat = only_titles.str.cat(sep=" ")

punct = '!"#$%&\'()*+,./:;<=>?@[\\]^_`{}~'   # `|` is not present here
transtab = str.maketrans(dict.fromkeys(punct, ''))
titles_no_punct = titles_cat.translate(transtab)

stop_words = stopwords.words('english')
word_tokens = word_tokenize(titles_no_punct.lower()) 

words_no_stops = [] 
for w in word_tokens:
    if w not in stop_words:
        words_no_stops.append(w)

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
words_no_stops
# Out:
# ['leucothrix',
#  'arctica',
#  'sp',
#  'nov',
#  'isolated',
#  'arctic',
#  'seawater',
#  'hyphobacterium',
#  'indicum',
#  'sp',
#  'nov',
#  'isolated',
#  'deep',
#  'seawater',
#  'emended',
#  'description',
#  'genus',
#  'hyphobacterium',
#  'sphingopyxis',
#  'lindanitolerans',
#  'sp',
#  'nov',
#  'strain',
#  'ws5a3pt',
#  'enriched',
#  'pesticide',
#  'disposal',
#  'site',
#  'mesosutterella',
#  'multiformis',
#  'gen',
#  'nov',
#  'sp',
#  'nov',
#  'member',
#  'family',
#  'sutterellaceae',
#  'sutterella',
#  'megalosphaeroides',
#  'sp',
#  'nov',
#  'isolated',
#  'human',
#  'faeces',
#  'acinetobacter',
#  'sichuanensis',
#  'sp',
#  'nov',
#  'recovered',
#  'hospital',
#  'sewage',
#  'china',
#  'enterobacter',
#  'sichuanensis',
#  'sp',
#  'nov',
#  'recovered',
#  'human',
#  'urine',
#  'kribbella',
#  'monticola',
#  'sp',
#  'nov',
#  'novel',
#  'actinomycete',
#  'isolated',
#  'soil',
#  'halomonas',
#  'litopenaei',
#  'sp',
#  'nov',
# ...

# %%
undesirable_words = ["comb","sp", "nov", "gen", "bacterium", "bacteria", "descriptions", "emended", "isolated", "genus", "novel", "member", "description", "member", "family", "species", "proposal", "et", "al", "new"]

filtered_words = [] 
for w in words_no_stops:
    if w not in undesirable_words:
        filtered_words.append(w)

# %%
filtered_words
# Out:
# ['leucothrix',
#  'arctica',
#  'arctic',
#  'seawater',
#  'hyphobacterium',
#  'indicum',
#  'deep',
#  'seawater',
#  'hyphobacterium',
#  'sphingopyxis',
#  'lindanitolerans',
#  'strain',
#  'ws5a3pt',
#  'enriched',
#  'pesticide',
#  'disposal',
#  'site',
#  'mesosutterella',
#  'multiformis',
#  'sutterellaceae',
#  'sutterella',
#  'megalosphaeroides',
#  'human',
#  'faeces',
#  'acinetobacter',
#  'sichuanensis',
#  'recovered',
#  'hospital',
#  'sewage',
#  'china',
#  'enterobacter',
#  'sichuanensis',
#  'recovered',
#  'human',
#  'urine',
#  'kribbella',
#  'monticola',
#  'actinomycete',
#  'soil',
#  'halomonas',
#  'litopenaei',
#  'moderately',
#  'halophilic',
#  'exopolysaccharide-producing',
#  'shrimp',
#  'hatchery',
#  'alsobacter',
#  'soli',
#  'paddy',
#  'soil',
#  'alsobacter',
#  'alsobacteraceae',
#  'fam',
#  'microbacterium',
#  'halophytorum',
#  'endophytic',
#  'actinobacterium',
#  'halophytes',
#  'salinimonas',
#  'sediminis',
# ...

# %%
import numpy as np

#x, y = np.ogrid[:300, :300]

#mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
#mask = 255 * mask.astype(int)

#mask = np.array(Image.open("bac_icon.png"))

# %% [markdown]
# # Figure 10

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud(width=2000, height=1000, max_words=300, background_color="white").generate(" ".join(filtered_words))
#wordcloud = WordCloud(width=28, height=22, max_words=300, background_color="white", mask=mask).generate(" ".join(filtered_words))

# Display the generated image:
#plt.figure(figsize=[14,11])
plt.axis("off")
plt.tight_layout(pad=0)
plt.imshow(wordcloud,interpolation="none")
plt.savefig("wordcloud.png", dpi=600, interpolation='none')
