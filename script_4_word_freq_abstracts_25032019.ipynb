# %%
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords
import seaborn as sns
from nltk.tokenize import word_tokenize 
from nltk.collocations import *
from nltk.stem import WordNetLemmatizer
from collections import Counter
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib.pyplot import savefig
from matplotlib import rcParams

# %%
papers = pd.read_csv("tabela_1_ed_sem_2019.csv", index_col=[0])

# %%
papers.head(5)
# Out:
#                                              Journal  \
# 0  International journal of systematic and evolut...
# 1  International journal of systematic and evolut...
# 4  International journal of systematic and evolut...
# 5  International journal of systematic and evolut...
# 6  International journal of systematic and evolut...
#
#                                                Title  \
# 0  Leucothrix arctica sp. nov., isolated from Arc...
# 1  Hyphobacterium indicum sp. nov., isolated from...
# 4  Sphingopyxis lindanitolerans sp. nov. strain W...
# 5  Mesosutterella multiformis gen. nov., sp. nov....
# 6  Acinetobacter sichuanensis sp. nov., recovered...
#
#                                              Authors  Year  \
# 0  ['Baek Kiwoon' 'Choi Ahyoung' 'Lee Yung Mi' 'L...  2018
# 1  ['Ruan Chu-Jin' 'Zheng Xiao-Wei' 'Wang Jian' '...  2018
# 4  ['Kaminski Michal A' 'Sobczak Adam' 'Spolnik G...  2018
# 5  ['Sakamoto Mitsuo' 'Ikeyama Nao' 'Kunihiro Tad...  2018
# 6  ['Qin Jiayuan' 'Hu Yiyi' 'Feng Yu' 'Lv Xiaoju'...  2018
#
#                                             Abstract
# 0  A Gram-stain-negative, non-motile, oxidase- an...
# 1  A novel aerobic, Gram-stain-negative bacterium...
# 4  An aerobic, Gram-stain-negative, rod-shaped, n...
# 5  Two novel, obligately anaerobic, Gram-stain-ne...
# 6  A novel Acinetobacter strain, WCHAc060041(T), ...

# %%
abstracts_full = papers[["Abstract", "Year"]]

# %%
stop = stopwords.words('english')

# %%
def freq_words_by_year(year):
    abstracts_year = abstracts_full[abstracts_full["Year"] == year]["Abstract"]
    abstracts_year_cat = abstracts_year.str.cat(sep=" ")
    
    punct = '!"#$%&\'()*+,./:;<=>?@[\\]^_`{}~'   # `|` is not present here
    transtab = str.maketrans(dict.fromkeys(punct, ''))
    abstracts_year_no_punct = abstracts_year_cat.translate(transtab)
    
    stop_words = stopwords.words('english')
    word_tokens_year = word_tokenize(abstracts_year_no_punct.lower()) 
    
    filtered_sentence_year = [] 
    for w in word_tokens_year: 
        if w not in stop_words: 
            filtered_sentence_year.append(w)
    
    #retirar a lematization, 16S é removido
    '''
    wordnet_lemmatizer = WordNetLemmatizer()
    lemmatized_year = []
    
    
    for w in filtered_sentence_year:
        lemmatized_w = wordnet_lemmatizer.lemmatize(w)
        lemmatized_year.append(lemmatized_w)
    '''
        
    freq_dict = Counter(filtered_sentence_year)

    freq_df = pd.DataFrame.from_dict(freq_dict, orient='index').reset_index()
    freq_df.columns = ["word", "freq"]
    
    freq_df.to_csv("{}_word_freq.csv".format(year))

# %%
for i in range(2001,2019):
    freq_words_by_year(i)

# %%
#freq de todos
abstracts_all = abstracts_full["Abstract"]
abstracts_cat = abstracts_all.str.cat(sep=" ")

punct = '!"#$%&\'()*+,./:;<=>?@[\\]^_`{}~'   # `|` is not present here
transtab = str.maketrans(dict.fromkeys(punct, ''))
abstracts_no_punct = abstracts_cat.translate(transtab)

stop_words = stopwords.words('english')
word_tokens = word_tokenize(abstracts_no_punct.lower()) 

filtered_sentence = [] 
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

#retirar a lematization, 16S é removido
'''
wordnet_lemmatizer = WordNetLemmatizer()
lemmatized_year = []


for w in filtered_sentence_year:
lemmatized_w = wordnet_lemmatizer.lemmatize(w)
lemmatized_year.append(lemmatized_w)
'''

freq_dict = Counter(filtered_sentence)

freq_df = pd.DataFrame.from_dict(freq_dict, orient='index').reset_index()
freq_df.columns = ["word", "all"]

freq_df.to_csv("all_word_freq.csv")

# %%
df_2001 = pd.read_table('2001_word_freq.csv', sep=',', index_col=0)
df_2002 = pd.read_table('2002_word_freq.csv', sep=',', index_col=0)
df_2003 = pd.read_table('2003_word_freq.csv', sep=',', index_col=0)
df_2004 = pd.read_table('2004_word_freq.csv', sep=',', index_col=0)
df_2005 = pd.read_table('2005_word_freq.csv', sep=',', index_col=0)
df_2006 = pd.read_table('2006_word_freq.csv', sep=',', index_col=0)
df_2007 = pd.read_table('2007_word_freq.csv', sep=',', index_col=0)
df_2008 = pd.read_table('2008_word_freq.csv', sep=',', index_col=0)
df_2009 = pd.read_table('2009_word_freq.csv', sep=',', index_col=0)
df_2010 = pd.read_table('2010_word_freq.csv', sep=',', index_col=0)
df_2011 = pd.read_table('2011_word_freq.csv', sep=',', index_col=0)
df_2012 = pd.read_table('2012_word_freq.csv', sep=',', index_col=0)
df_2013 = pd.read_table('2013_word_freq.csv', sep=',', index_col=0)
df_2014 = pd.read_table('2014_word_freq.csv', sep=',', index_col=0)
df_2015 = pd.read_table('2015_word_freq.csv', sep=',', index_col=0)
df_2016 = pd.read_table('2016_word_freq.csv', sep=',', index_col=0)
df_2017 = pd.read_table('2017_word_freq.csv', sep=',', index_col=0)
df_2018 = pd.read_table('2018_word_freq.csv', sep=',', index_col=0)

# %%
from functools import reduce

dfs = [df_2001, df_2002, df_2003, df_2004, df_2005, df_2006, df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018]
df_final = reduce(lambda left,right: pd.merge(left,right,on='word',how='outer'), dfs)
df_final.columns = ["word", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018" ]

# %%
df_final = df_final.set_index("word")
df_final
# Out:
#                 2001   2002   2003   2004   2005   2006   2007   2008   2009  \
# word
# polyphasic      35.0   37.0   66.0   80.0  109.0  142.0  189.0  164.0  178.0
# approach        16.0   19.0   20.0   25.0   44.0   57.0   82.0   64.0   98.0
# used            16.0   34.0   34.0   31.0   39.0   22.0   27.0   35.0   38.0
# establish        2.0    1.0    2.0    5.0    4.0    1.0    4.0    6.0    2.0
# taxonomic       47.0   59.0   72.0   92.0  106.0  131.0  167.0  147.0  168.0
# position        19.0   20.0   29.0   41.0   39.0   54.0   62.0   58.0   64.0
# two            118.0  149.0  143.0  197.0  237.0  245.0  278.0  191.0  267.0
# actinomycetes    4.0    3.0    1.0    6.0    4.0    7.0    5.0    3.0    6.0
# isolated       170.0  201.0  228.0  284.0  342.0  394.0  471.0  465.0  500.0
# namibian         1.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# soil            21.0   27.0   37.0   60.0   56.0   75.0  110.0  112.0   88.0
# shown           14.0   10.0   14.0   17.0   26.0   30.0   33.0   26.0   22.0
# utilise          1.0    NaN    1.0    NaN    NaN    NaN    NaN    NaN    NaN
# nitrile          1.0    NaN    NaN    NaN    NaN    NaN    4.0    3.0    3.0
# compounds       14.0   18.0   16.0   18.0   15.0   19.0   13.0   17.0   19.0
# growth         138.0  172.0  167.0  182.0  208.0  230.0  245.0  236.0  284.0
# substrates      22.0   20.0   21.0   15.0   15.0   22.0   15.0   20.0   15.0
# organisms       34.0   41.0   43.0   59.0   38.0   36.0   33.0   26.0   25.0
# strains        342.0  402.0  477.0  603.0  701.0  665.0  789.0  605.0  828.0
# nam-bn063at      2.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# nam-bn063b       1.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# chemical         8.0    6.0   18.0   17.0    7.0   11.0    8.0    6.0   10.0
# morphological   29.0   31.0   36.0   44.0   42.0   43.0   53.0   49.0   56.0
# properties      38.0   47.0   66.0   83.0   83.0   94.0  109.0   91.0   89.0
# consistent      14.0   13.0   15.0   17.0   17.0   25.0   23.0   24.0   29.0
# assignment       6.0    5.0    6.0    9.0   12.0   12.0   12.0   13.0   23.0
# genus          222.0  294.0  351.0  414.0  533.0  632.0  878.0  837.0  920.0
# gordonia         5.0    5.0   14.0    NaN    5.0   24.0    8.0    5.0   16.0
# direct           2.0    2.0    4.0    3.0    NaN    2.0    NaN    1.0    NaN
# 165              9.0   15.0    NaN    NaN    1.0    NaN    1.0    NaN    NaN
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# gifthornensis    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ab18-032t        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2016023t         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 45673t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ss1-76t          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# sangjuense       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 52159t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 31375t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# neau-fjl1t       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 100596t          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 47284t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# maps             NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# bruuniana        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# g0146t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 69503t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 111191t          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# g4122t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 69496t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 111192t          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# g4070t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 69505t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 111193t          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 96448t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# anteiso-c171b    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017055t         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 39924t           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# tx0653t          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 951-908          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# metallum         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 112495t          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                 2010    2011    2012    2013    2014    2015    2016    2017  \
# word
# polyphasic     150.0   173.0   155.0   302.0   262.0   322.0   298.0   319.0
# approach        81.0    97.0    97.0   170.0   129.0   158.0   180.0   160.0
# used            27.0    27.0    39.0    50.0    33.0    52.0    32.0    32.0
# establish        2.0     3.0     2.0     3.0     3.0    10.0     8.0     7.0
# taxonomic      153.0   167.0   156.0   255.0   221.0   256.0   248.0   239.0
# position        77.0    66.0    71.0   109.0    73.0   100.0   105.0    94.0
# two            216.0   239.0   246.0   427.0   401.0   454.0   385.0   448.0
# actinomycetes    3.0     2.0     6.0     7.0     4.0     2.0     3.0     2.0
# isolated       491.0   509.0   546.0   835.0   747.0   888.0   763.0   847.0
# namibian         NaN     NaN     NaN     NaN     NaN     NaN     1.0     NaN
# soil           115.0   116.0   124.0   159.0   184.0   216.0   178.0   198.0
# shown           37.0    21.0    16.0    53.0    29.0    23.0    19.0    15.0
# utilise          NaN     NaN     NaN     1.0     NaN     NaN     NaN     NaN
# nitrile          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# compounds       21.0    19.0    27.0    23.0    12.0    28.0    21.0    16.0
# growth         237.0   243.0   274.0   359.0   360.0   388.0   333.0   397.0
# substrates      18.0    14.0    17.0    25.0    13.0    18.0    10.0    20.0
# organisms       23.0    19.0    20.0    21.0    16.0    16.0     6.0    12.0
# strains        765.0   777.0   743.0  1082.0  1052.0  1050.0   879.0   998.0
# nam-bn063at      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# nam-bn063b       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# chemical         8.0     7.0    13.0    15.0    15.0    11.0     5.0     6.0
# morphological   33.0    55.0    58.0    73.0    73.0    92.0    72.0    75.0
# properties      90.0    90.0   126.0   160.0   134.0   147.0   137.0   141.0
# consistent      16.0    32.0    30.0    30.0    36.0    34.0    34.0    22.0
# assignment      12.0    14.0    10.0    12.0    10.0    16.0     3.0     9.0
# genus          987.0  1067.0  1109.0  1723.0  1629.0  1818.0  1500.0  1680.0
# gordonia         NaN    16.0     7.0    12.0     9.0     NaN    11.0     4.0
# direct           1.0     1.0     3.0     2.0     1.0     5.0     NaN     NaN
# 165              2.0     1.0     2.0     3.0     3.0     2.0     NaN     1.0
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# gifthornensis    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ab18-032t        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2016023t         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 45673t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ss1-76t          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# sangjuense       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 52159t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 31375t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# neau-fjl1t       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100596t          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 47284t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# maps             NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# bruuniana        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# g0146t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 69503t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 111191t          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# g4122t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 69496t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 111192t          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# g4070t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 69505t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 111193t          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 96448t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# anteiso-c171b    NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2017055t         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 39924t           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# tx0653t          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 951-908          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# metallum         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 112495t          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                  2018
# word
# polyphasic      249.0
# approach        145.0
# used             23.0
# establish         8.0
# taxonomic       171.0
# position         72.0
# two             322.0
# actinomycetes     3.0
# isolated        636.0
# namibian          NaN
# soil            180.0
# shown            14.0
# utilise           1.0
# nitrile           NaN
# compounds        11.0
# growth          259.0
# substrates        7.0
# organisms         8.0
# strains         623.0
# nam-bn063at       NaN
# nam-bn063b        NaN
# chemical         14.0
# morphological    73.0
# properties      106.0
# consistent       26.0
# assignment        6.0
# genus          1209.0
# gordonia          NaN
# direct            NaN
# 165               2.0
# ...               ...
# gifthornensis     1.0
# ab18-032t         1.0
# 2016023t          1.0
# 45673t            1.0
# ss1-76t           5.0
# sangjuense        1.0
# 52159t            1.0
# 31375t            1.0
# neau-fjl1t        4.0
# 100596t           1.0
# 47284t            1.0
# maps              1.0
# bruuniana         1.0
# g0146t            1.0
# 69503t            1.0
# 111191t           1.0
# g4122t            1.0
# 69496t            1.0
# 111192t           1.0
# g4070t            1.0
# 69505t            1.0
# 111193t           1.0
# 96448t            5.0
# anteiso-c171b     1.0
# 2017055t          1.0
# 39924t            1.0
# tx0653t           2.0
# 951-908           1.0
# metallum          1.0
# 112495t           1.0
#
# [80455 rows x 18 columns]

# %%
n_year = pd.DataFrame(abstracts_full["Year"].value_counts()).reset_index()
n_year.columns = ["Year", "Frequency"]
n_year = n_year.sort_values(by="Year")
n_year_ed = n_year.set_index("Year")
n_year_transposed = n_year_ed.transpose()
n_year_transposed.columns = ["2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"]
n_year_transposed
# Out:
#            2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# Frequency   179   234   269   330   376   416   502   486   529   534   534
#
#            2012  2013  2014  2015  2016  2017  2018
# Frequency   560   853   757   903   775   867   647

# %%
relative = df_final.div(n_year_transposed.iloc[0])

# %%
relative
# Out:
#                    2001      2002      2003      2004      2005      2006  \
# word
# polyphasic     0.195531  0.158120  0.245353  0.242424  0.289894  0.341346
# approach       0.089385  0.081197  0.074349  0.075758  0.117021  0.137019
# used           0.089385  0.145299  0.126394  0.093939  0.103723  0.052885
# establish      0.011173  0.004274  0.007435  0.015152  0.010638  0.002404
# taxonomic      0.262570  0.252137  0.267658  0.278788  0.281915  0.314904
# position       0.106145  0.085470  0.107807  0.124242  0.103723  0.129808
# two            0.659218  0.636752  0.531599  0.596970  0.630319  0.588942
# actinomycetes  0.022346  0.012821  0.003717  0.018182  0.010638  0.016827
# isolated       0.949721  0.858974  0.847584  0.860606  0.909574  0.947115
# namibian       0.005587       NaN       NaN       NaN       NaN       NaN
# soil           0.117318  0.115385  0.137546  0.181818  0.148936  0.180288
# shown          0.078212  0.042735  0.052045  0.051515  0.069149  0.072115
# utilise        0.005587       NaN  0.003717       NaN       NaN       NaN
# nitrile        0.005587       NaN       NaN       NaN       NaN       NaN
# compounds      0.078212  0.076923  0.059480  0.054545  0.039894  0.045673
# growth         0.770950  0.735043  0.620818  0.551515  0.553191  0.552885
# substrates     0.122905  0.085470  0.078067  0.045455  0.039894  0.052885
# organisms      0.189944  0.175214  0.159851  0.178788  0.101064  0.086538
# strains        1.910615  1.717949  1.773234  1.827273  1.864362  1.598558
# nam-bn063at    0.011173       NaN       NaN       NaN       NaN       NaN
# nam-bn063b     0.005587       NaN       NaN       NaN       NaN       NaN
# chemical       0.044693  0.025641  0.066914  0.051515  0.018617  0.026442
# morphological  0.162011  0.132479  0.133829  0.133333  0.111702  0.103365
# properties     0.212291  0.200855  0.245353  0.251515  0.220745  0.225962
# consistent     0.078212  0.055556  0.055762  0.051515  0.045213  0.060096
# assignment     0.033520  0.021368  0.022305  0.027273  0.031915  0.028846
# genus          1.240223  1.256410  1.304833  1.254545  1.417553  1.519231
# gordonia       0.027933  0.021368  0.052045       NaN  0.013298  0.057692
# direct         0.011173  0.008547  0.014870  0.009091       NaN  0.004808
# 165            0.050279  0.064103       NaN       NaN  0.002660       NaN
# ...                 ...       ...       ...       ...       ...       ...
# 69503t              NaN       NaN       NaN       NaN       NaN  0.001546
# 111191t             NaN       NaN       NaN       NaN       NaN  0.001546
# g4122t              NaN       NaN       NaN       NaN       NaN  0.001546
# 69496t              NaN       NaN       NaN       NaN       NaN  0.001546
# 111192t             NaN       NaN       NaN       NaN       NaN  0.001546
# g4070t              NaN       NaN       NaN       NaN       NaN  0.001546
# 69505t              NaN       NaN       NaN       NaN       NaN  0.001546
# 111193t             NaN       NaN       NaN       NaN       NaN  0.001546
# 96448t              NaN       NaN       NaN       NaN       NaN  0.007728
# anteiso-c171b       NaN       NaN       NaN       NaN       NaN  0.001546
# 2017055t            NaN       NaN       NaN       NaN       NaN  0.001546
# 39924t              NaN       NaN       NaN       NaN       NaN  0.001546
# tx0653t             NaN       NaN       NaN       NaN       NaN  0.003091
# 951-908             NaN       NaN       NaN       NaN       NaN  0.001546
# metallum            NaN       NaN       NaN       NaN       NaN  0.001546
# 112495t             NaN       NaN       NaN       NaN       NaN  0.001546
#
# [80455 rows x 18 columns]

# %%
transposed_relative = relative.T
transposed_relative
# Out:
# word  polyphasic  approach      used  establish  taxonomic  position  \
# 2001    0.195531  0.089385  0.089385   0.011173   0.262570  0.106145
# 2002    0.158120  0.081197  0.145299   0.004274   0.252137  0.085470
# 2003    0.245353  0.074349  0.126394   0.007435   0.267658  0.107807
# 2004    0.242424  0.075758  0.093939   0.015152   0.278788  0.124242
# 2005    0.289894  0.117021  0.103723   0.010638   0.281915  0.103723
# 2006    0.341346  0.137019  0.052885   0.002404   0.314904  0.129808
# 2007    0.376494  0.163347  0.053785   0.007968   0.332669  0.123506
# 2008    0.337449  0.131687  0.072016   0.012346   0.302469  0.119342
# 2009    0.336484  0.185255  0.071834   0.003781   0.317580  0.120983
# 2010    0.280899  0.151685  0.050562   0.003745   0.286517  0.144195
# 2011    0.323970  0.181648  0.050562   0.005618   0.312734  0.123596
# 2012    0.276786  0.173214  0.069643   0.003571   0.278571  0.126786
# 2013    0.354045  0.199297  0.058617   0.003517   0.298945  0.127784
# 2014    0.346103  0.170410  0.043593   0.003963   0.291942  0.096433
# 2015    0.356589  0.174972  0.057586   0.011074   0.283499  0.110742
# 2016    0.384516  0.232258  0.041290   0.010323   0.320000  0.135484
# 2017    0.367935  0.184544  0.036909   0.008074   0.275663  0.108420
# 2018    0.384853  0.224111  0.035549   0.012365   0.264297  0.111283
#
# word       two  actinomycetes  isolated  namibian    ...       69505t  \
# 2001  0.659218       0.022346  0.949721  0.005587    ...          NaN
# 2002  0.636752       0.012821  0.858974       NaN    ...          NaN
# 2003  0.531599       0.003717  0.847584       NaN    ...          NaN
# 2004  0.596970       0.018182  0.860606       NaN    ...          NaN
# 2005  0.630319       0.010638  0.909574       NaN    ...          NaN
# 2006  0.588942       0.016827  0.947115       NaN    ...          NaN
# 2007  0.553785       0.009960  0.938247       NaN    ...          NaN
# 2008  0.393004       0.006173  0.956790       NaN    ...          NaN
# 2009  0.504726       0.011342  0.945180       NaN    ...          NaN
# 2010  0.404494       0.005618  0.919476       NaN    ...          NaN
# 2011  0.447566       0.003745  0.953184       NaN    ...          NaN
# 2012  0.439286       0.010714  0.975000       NaN    ...          NaN
# 2013  0.500586       0.008206  0.978898       NaN    ...          NaN
# 2014  0.529723       0.005284  0.986790       NaN    ...          NaN
# 2015  0.502769       0.002215  0.983389       NaN    ...          NaN
# 2016  0.496774       0.003871  0.984516  0.001290    ...          NaN
# 2017  0.516724       0.002307  0.976932       NaN    ...          NaN
# 2018  0.497682       0.004637  0.982998       NaN    ...     0.001546
#
# word   111193t    96448t  anteiso-c171b  2017055t    39924t   tx0653t  \
# 2001       NaN       NaN            NaN       NaN       NaN       NaN
# 2002       NaN       NaN            NaN       NaN       NaN       NaN
# 2003       NaN       NaN            NaN       NaN       NaN       NaN
# 2004       NaN       NaN            NaN       NaN       NaN       NaN
# 2005       NaN       NaN            NaN       NaN       NaN       NaN
# 2006       NaN       NaN            NaN       NaN       NaN       NaN
# 2007       NaN       NaN            NaN       NaN       NaN       NaN
# 2008       NaN       NaN            NaN       NaN       NaN       NaN
# 2009       NaN       NaN            NaN       NaN       NaN       NaN
# 2010       NaN       NaN            NaN       NaN       NaN       NaN
# 2011       NaN       NaN            NaN       NaN       NaN       NaN
# 2012       NaN       NaN            NaN       NaN       NaN       NaN
# 2013       NaN       NaN            NaN       NaN       NaN       NaN
# 2014       NaN       NaN            NaN       NaN       NaN       NaN
# 2015       NaN       NaN            NaN       NaN       NaN       NaN
# 2016       NaN       NaN            NaN       NaN       NaN       NaN
# 2017       NaN       NaN            NaN       NaN       NaN       NaN
# 2018  0.001546  0.007728       0.001546  0.001546  0.001546  0.003091
#
# word   951-908  metallum   112495t
# 2001       NaN       NaN       NaN
# 2002       NaN       NaN       NaN
# 2003       NaN       NaN       NaN
# 2004       NaN       NaN       NaN
# 2005       NaN       NaN       NaN
# 2006       NaN       NaN       NaN
# 2007       NaN       NaN       NaN
# 2008       NaN       NaN       NaN
# 2009       NaN       NaN       NaN
# 2010       NaN       NaN       NaN
# 2011       NaN       NaN       NaN
# 2012       NaN       NaN       NaN
# 2013       NaN       NaN       NaN
# 2014       NaN       NaN       NaN
# 2015       NaN       NaN       NaN
# 2016       NaN       NaN       NaN
# 2017       NaN       NaN       NaN
# 2018  0.001546  0.001546  0.001546
#
# [18 rows x 80455 columns]

# %%
transposed_relative.to_csv("trans_relative_word.csv")

# %% [markdown]
# # Genus

# %%
genus = transposed_relative[['bacillus', 'streptomyces', 'paenibacillus', 'flavobacterium', 'pseudomonas', 'lactobacillus', 'sphingomonas', 'chryseobacterium', 'mycobacterium', 'pedobacter', 'vibrio', 'halomonas', 'clostridium', 'nocardia', 'microbacterium', 'burkholderia', 'micromonospora', 'streptococcus', 'deinococcus', 'lysobacter']].T

# %%
#opcional para o artigo
fig, ax = plt.subplots(figsize=(19,5))
ax.xaxis.set_tick_params(width=1.5, labelsize=14)
ax.yaxis.set_tick_params(width=1.5, labelsize=14)
#pal = sns.color_palette("Set1")
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
sns.heatmap(genus, cmap="inferno")

# %%
markers = transposed_relative[['gyrb', 'rpob', 'reca', 'atpd', 'rpoa', 'rpod', 'glnii', 'dnak', "recn"]].T

# %%
methods = transposed_relative[['rrna', 'phylogenetic', 'fatty', 'phenotypic', 'gc', 'dna-dna', 'lipids', 'chemotaxonomic', 'quinone', 'genomic', 'physiological', 'genotypic', 'biochemical', 'lipid', 'peptidoglycan', 'morphological', 'genome', 'gyrb', 'rpob', 'reca', 'atpd', 'rpoa', 'rpod', 'glnii', 'dnak', "recn", 'ani', 'anib', 'ggdc', 'dddh', 'gani']].T

# %% [markdown]
# # Origin

# %%
country_env = transposed_relative[['soil', 'water', 'lake', 'human', 'plant', 'root','china', 'korea', 'japan', 'india', 'taiwan', 'usa', 'spain', 'russia', 'germany', 'france']].T

# %%
#opcional para o artigo
fig, ax = plt.subplots(figsize=(15,8))
ax.xaxis.set_tick_params(width=1.5, labelsize=14)
ax.yaxis.set_tick_params(width=1.5, labelsize=14)
#pal = sns.color_palette("Set1")
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
sns.heatmap(country_env, cmap="inferno", cbar_kws = {"shrink": 0.3})
fig.savefig("origin.svg")

# %% [markdown]
# # Methods

# %%
methods2 = transposed_relative[["phylogenetic","phenotypic", "chemotaxonomic","genomic", "genotypic", "rrna", "gyrb", "rpob", "reca", "atpd", "rpoa", "rpod", "glnii", "dnak", "recn", "physiological", "biochemical", "morphological", "fatty", "lipids", "quinone", "peptidoglycan", "gc","dna-dna", "genome", "ani", "anib", "ggdc", "dddh", "gani"]].T

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax.xaxis.set_tick_params(width=1.5, labelsize=14)
ax.yaxis.set_tick_params(width=1.5, labelsize=14)
#pal = sns.color_palette("Set1")
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
sns.heatmap(methods, cmap="inferno", cbar_kws = {"shrink": 0.3})
fig.savefig("tests.svg")

# %% [markdown]
# # Phenotype

# %%
phenotype2 = transposed_relative[['aerobic', 'anaerobic', 'halophilic','thermophilic', "mesophilic", 'heterotrophic', "autotrophic", 'catalase-positive', 'catalase-negative', 'oxidase-positive', "oxidase-negative", 'rod-shaped', 'rods', 'rod', "cocci", "coccus", 'coccoid', 'mycelium','gram-negative', 'gram-stain-negative', 'gram-staining-negative', 'gram-positive', 'gram-stain-positive', 'non-motile', 'motile', 'non-spore-forming', 'endospore-forming', 'spore-forming']].T

# %%
fig, ax = plt.subplots(figsize=(15,14))
ax.xaxis.set_tick_params(width=1.5, labelsize=14)
ax.yaxis.set_tick_params(width=1.5, labelsize=14)
#pal = sns.color_palette("Set1")
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
sns.heatmap(phenotype2, cmap="inferno", cbar_kws = {"shrink": 0.3})
fig.savefig("characterization.svg")
