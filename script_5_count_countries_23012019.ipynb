# %%
import xml.etree.ElementTree as et
from affiliation_parser import parse_affil
import pandas as pd
# Out:
# use trained model from /home/fernando/affiliation_parser_data

# %%
tree = et.parse("sp_nov_2001_2018_pubmed_16012019_ed.xml")
root = tree.getroot()

# %%
#Journals
with open("tabela_countries.txt", "w") as file:
    file.write("Journal" + "\t" + "Article Title" + "\t" + "Year" + "\t" + "Affiliation" + "\t" + "Country" + "\n")
    for article_set in root.findall("PubmedArticleSet"):
        for pubmed_article in article_set.findall("PubmedArticle"):
            for medline_citation in pubmed_article.findall("MedlineCitation"):
                for article in medline_citation.findall("Article"):
                    title = article.find("ArticleTitle").text
                    for author_list in article.findall("AuthorList"):
                        first_author = author_list[0]
                        aff_info = first_author.find("AffiliationInfo")
                        try:
                            affiliation = aff_info.find("Affiliation").text
                            country_fa = parse_affil(affiliation)["country"]
                        except:
                            country_fa = ""
                    for journal in article.findall("Journal"):
                        journal_title = journal.find("Title").text
                        for journal_issue in journal.findall("JournalIssue"):
                            for pubdate in journal_issue.findall("PubDate"):
                                try:
                                    year = pubdate.find("Year").text
                                    pass
                                except:
                                    year = pubdate.find("MedlineDate").text.split(" ")[0]
                                file.write(journal_title + "\t" + title + "\t" + year + "\t" + affiliation + "\t" + country_fa + "\n")

# %%
df = pd.read_csv("tabela_countries.txt", sep="\t")

# %%
falta_country = df[df["Country"].isna()]
falta_country.to_csv("falta_country.csv")

# %%
sem_2019 = df[df["Year"] != 2019]

# %%
df[df["Year"] == 2019]
# Out:
#                                   Journal  \
# 0  Journal of microbiology (Seoul, Korea)
# 3  Journal of microbiology (Seoul, Korea)
# 4  Journal of microbiology (Seoul, Korea)
#
#                                        Article Title  Year  \
# 0  Mediterraneibacter butyricigenes sp. nov., a b...  2019
# 3  Gramella fulva sp. nov., isolated from a dry s...  2019
# 4  Flavisolibacter aluminii sp. nov., a novel mem...  2019
#
#                                          Affiliation      Country
# 0  Korean Collection for Type Cultures, Biologica...  south korea
# 3  Department of Biology, College of Natural Scie...  south korea
# 4  Department of Agricultural Biotechnology and R...  south korea

# %%
sem_2019.to_csv("tabela_countries_s_2019.csv")

# %%
sem_2019
# Out:
#                                                 Journal  \
# 1     International journal of systematic and evolut...
# 2     International journal of systematic and evolut...
# 5     International journal of systematic and evolut...
# 6     International journal of systematic and evolut...
# 7     International journal of systematic and evolut...
# 8     International journal of systematic and evolut...
# 9     International journal of systematic and evolut...
# 10    International journal of systematic and evolut...
# 11    International journal of systematic and evolut...
# 12    International journal of systematic and evolut...
# 13    International journal of systematic and evolut...
# 14    International journal of systematic and evolut...
# 15    International journal of systematic and evolut...
# 16    International journal of systematic and evolut...
# 17    International journal of systematic and evolut...
# 18               Journal of microbiology (Seoul, Korea)
# 19    International journal of systematic and evolut...
# 20    International journal of systematic and evolut...
# 21    International journal of systematic and evolut...
# 22    International journal of systematic and evolut...
# 23    International journal of systematic and evolut...
# 24    International journal of systematic and evolut...
# 25    International journal of systematic and evolut...
# 26    International journal of systematic and evolut...
# 27    International journal of systematic and evolut...
# 28    International journal of systematic and evolut...
# 29    International journal of systematic and evolut...
# 30    International journal of systematic and evolut...
# 31    International journal of systematic and evolut...
# 32    International journal of systematic and evolut...
# ...                                                 ...
# 9724  International journal of systematic and evolut...
# 9725  International journal of systematic and evolut...
# 9726  International journal of systematic and evolut...
# 9727  International journal of systematic and evolut...
# 9728  International journal of systematic and evolut...
# 9729  International journal of systematic and evolut...
# 9730  International journal of systematic and evolut...
# 9731  International journal of systematic and evolut...
# 9732  International journal of systematic and evolut...
# 9733                    Microbiology (Reading, England)
# 9734                   Journal of clinical microbiology
# 9735  International journal of systematic and evolut...
# 9736  International journal of systematic and evolut...
# 9737  International journal of systematic and evolut...
# 9738  International journal of systematic and evolut...
# 9739  International journal of systematic and evolut...
# 9740  International journal of systematic and evolut...
# 9741  International journal of systematic and evolut...
# 9742  International journal of systematic and evolut...
# 9743  International journal of systematic and evolut...
# 9744  International journal of systematic and evolut...
# 9745  International journal of systematic and evolut...
# 9746  International journal of systematic and evolut...
# 9747  International journal of systematic and evolut...
# 9748  International journal of systematic and evolut...
# 9749  International journal of systematic and evolut...
# 9750  International journal of systematic and evolut...
# 9751  International journal of systematic and evolut...
# 9752                    Journal of applied microbiology
# 9753                   Journal of clinical microbiology
#
#                                           Article Title  Year  \
# 1     Leucothrix arctica sp. nov., isolated from Arc...  2018
# 2     Hyphobacterium indicum sp. nov., isolated from...  2018
# 5     Sphingopyxis lindanitolerans sp. nov. strain W...  2018
# 6     Mesosutterella multiformis gen. nov., sp. nov....  2018
# 7     Acinetobacter sichuanensis sp. nov., recovered...  2018
# 8     Enterobacter sichuanensis sp. nov., recovered ...  2018
# 9     Kribbella monticola sp. nov., a novel actinomy...  2018
# 10    Halomonas litopenaei sp. nov., a moderately ha...  2018
# 11    Alsobacter soli sp. nov., a novel bacterium is...  2018
# 12    Microbacterium halophytorum sp. nov., a novel ...  2018
# 13    Salinimonas sediminis sp. nov., a piezophilic ...  2018
# 14    Nocardioides houyundeii sp. nov., isolated fro...  2018
# 15    Clostridium composti sp. nov., a new anaerobic...  2018
# 16    Taxonomic status of Corynebacterium diphtheria...  2018
# 17    Flavobacterium sediminis sp. nov., a starch-de...  2018
# 18    Roseovarius tibetensis sp. nov., a halophilic ...  2018
# 19    Arthrobacter silvisoli sp. nov., isolated from...  2018
# 20    Alteromonas indica sp. nov., isolated from sur...  2018
# 21    Actinomyces tangfeifanii sp. nov., isolated fr...  2018
# 22    Reclassification of Eubacterium hallii as Anae...  2018
# 23    Litorivita pollutaquae gen. nov., sp. nov., a ...  2018
# 24    Prevotella rara sp. nov., isolated from human ...  2018
# 25    Jeotgalibacillus proteolyticus sp. nov., a pro...  2018
# 26    Paracoccus salipaludis sp. nov., isolated from...  2018
# 27    Minwuia thermotolerans gen. nov., sp. nov., a ...  2018
# 28    Microbispora soli sp. nov., isolated from soil...  2018
# 29    Lactococcus termiticola sp. nov., isolated fro...  2018
# 30    Flavobacterium riviphilum sp. nov., isolated f...  2018
# 31    Flavobacterium magnum sp. nov., Flavobacterium...  2018
# 32    Zobellella endophytica sp. nov., isolated from...  2018
# ...                                                 ...   ...
# 9724  Schineria larvae gen. nov., sp. nov., isolated...  2001
# 9725  Enterococcus villorum sp. nov., an enteroadher...  2001
# 9726  Desulfomonile limimaris sp. nov., an anaerobic...  2001
# 9727  Streptimonospora salina gen. nov., sp. nov., a...  2001
# 9728  Pseudomonas alcaliphila sp. nov., a novel facu...  2001
# 9729  Dethiosulfovibrio russensis sp. nov., Dethosul...  2001
# 9730  Saccharopolyspora flava sp. nov. and Saccharop...  2001
# 9731  Characterization of two novel saccharolytic, a...  2001
# 9732  Proposal of Sphingomonas wittichii sp. nov. fo...  2001
# 9733  Characterization of lactobacilli from Scotch m...  2001
# 9734  Tsukamurella strandjordae sp. nov., a proposed...  2001
# 9735  Ornithinimicrobium humiphilum gen. nov., sp. n...  2001
# 9736  Sphingomonas alaskensis sp. nov., a dominant b...  2001
# 9737  Reclassification of [Pseudomonas] doudoroffii ...  2001
# 9738  Vibrio cyclotrophicus sp. nov., a polycyclic a...  2001
# 9739  Arcanobacterium pluranimalium sp. nov., isolat...  2001
# 9740  Lactobacillus cypricasei sp. nov., isolated fr...  2001
# 9741  Clostridium hiranonis sp. nov., a human intest...  2001
# 9742  Amycolatopsis sacchari sp. nov., a moderately ...  2001
# 9743  Reclassification of Desulfobacterium phenolicu...  2001
# 9744  Azospirillum doebereinerae sp. nov., a nitroge...  2001
# 9745  Herbaspirillum frisingense sp. nov., a new nit...  2001
# 9746  Actinomyces marimammalium sp. nov., from marin...  2001
# 9747  Carboxydobrachium pacificum gen. nov., sp. nov...  2001
# 9748  Desulfosporosinus meridiei sp. nov., a spore-f...  2001
# 9749  Clostridium hungatei sp. nov., a mesophilic, N...  2001
# 9750  Hyphomicrobium chloromethanicum sp. nov. and M...  2001
# 9751  Thioflavicoccus mobilis gen. nov., sp. nov., a...  2001
# 9752  Isolation and characterization of a novel hydr...  2001
# 9753  Nocardia africana sp. nov., a new pathogen iso...  2001
#
#                                             Affiliation  \
# 1     2​Freshwater Bioresources Research Bureau, Nak...
# 2     1​State Key Laboratory of Microbial Resources,...
# 5     1​Institute of Biochemistry and Biophysics, Po...
# 6     1​Microbe Division/Japan Collection of Microor...
# 7     1​Center of Infectious Diseases, West China Ho...
# 8     1​Center of Infectious Diseases, West China Ho...
# 9     1​Key Laboratory of Agriculture Biological Fun...
# 10    1​Fisheries College, Guangdong Ocean Universit...
# 11    1​Eco-Environmental Protection Research Instit...
# 12    1​Xinjiang Key Laboratory of Special Species C...
# 13    2​National Engineering Research Center for Oce...
# 14    1​Guangxi Key Laboratory of AIDS Prevention an...
# 15    1​ABS Research Support Center/Korean Collectio...
# 16    1​Institut Pasteur, Biodiversity and Epidemiol...
# 17    1​National Marine Biodiversity Institute of Ko...
# 18    State Key Laboratory of Lake Science and Envir...
# 19    1​School of Life Science, Northeast Agricultur...
# 20    College of Biological and Environmental Scienc...
# 21    1​State Key Laboratory of Infectious Disease P...
# 22    1​Laboratory of Microbiology, Wageningen Unive...
# 23    Key Laboratory of the Ministry of Education fo...
# 24    1​Department of Microbiology and Virology, Pir...
# 25    1​Key Laboratory of Coastal Biology and Utiliz...
# 26    1​Jiangsu Provincial Key Lab for Organic Solid...
# 27    1​College of Life Sciences, Zhejiang Sci-Tech ...
# 28    1​Department of Biology and Actinobacterial re...
# 29    1​Graduate School of Life and Environmental Sc...
# 30    1​Department of Marine Biotechnology, National...
# 31    1​Department of Public Health Sciences, Gradua...
# 32    1​State Key Laboratory of Tree Genetics and Br...
# ...                                                 ...
# 9724  Department of Microbiology, Eötvös Loránd Univ...
# 9725  Bacteria Collection, Laboratory of Microbiolog...
# 9726  Center for Microbial Ecology and Department of...
# 9727  Yunnan Institute of Microbiology, Yunnan Unive...
# 9728  Bioscience and Chemistry Division, Hokkaido Na...
# 9729  Laboratory of Ecology and Geochemical Activity...
# 9730  Institute of Microbiology, Chinese Academy of ...
# 9731  Department of Animal Sciences, University of I...
# 9732  Department of Microbiology and Immunology, Aic...
# 9733  International Centre for Brewing & Distilling,...
# 9734  Department of Laboratory Medicine, Division of...
# 9735  Hans-Knöll-Institut für Naturstoff-Forschung e...
# 9736  BCCM/LMG Bacteria Collection, University of Ge...
# 9737  The School of Sciences, University of Sunderla...
# 9738  Department of Microbiology, University of Wash...
# 9739  Department of Food Science and Technology, Uni...
# 9740  Department of Food Science and Technology, Uni...
# 9741  Japan Collection of Microorganisms, RIKEN, Wak...
# 9742  Department of Agricultural and Environmental S...
# 9743  Max-Planck-Institute for Marine Microbiology, ...
# 9744  GSF-National Research Centre for Environment a...
# 9745  GSF-National Research Center for Environment a...
# 9746  Department of Food Science and Technology, Uni...
# 9747  Institute of Microbiology, Russian Academy of ...
# 9748  Centre for Groundwater Studies, CSIRO Land and...
# 9749  Department of Microbiology, University of Mass...
# 9750  Department of Biological Sciences, University ...
# 9751  Institut für Meereskunde, Kiel, Germany. jimho...
# 9752  AEA Technology, Environment, Culham, Abingdon,...
# 9753  Department of Preventive Medicine and Public H...
#
#                        Country
# 1                  south korea
# 2                        china
# 5                       poland
# 6                        japan
# 7                        china
# 8                        china
# 9                        china
# 10                       china
# 11                       china
# 12                       china
# 13                       china
# 14                       china
# 15                 south korea
# 16                      france
# 17                 south korea
# 18                       china
# 19                       china
# 20                       china
# 21                       china
# 22                 netherlands
# 23                       china
# 24                      russia
# 25                       china
# 26                       china
# 27                       china
# 28                    thailand
# 29                       japan
# 30                      taiwan
# 31                 south korea
# 32                       china
# ...                        ...
# 9724                   hungary
# 9725                   belgium
# 9726  united states of america
# 9727                     china
# 9728                     japan
# 9729                    russia
# 9730                     china
# 9731  united states of america
# 9732                     japan
# 9733            united kingdom
# 9734  united states of america
# 9735                   germany
# 9736                   belgium
# 9737            united kingdom
# 9738  united states of america
# 9739            united kingdom
# 9740            united kingdom
# 9741                     japan
# 9742            united kingdom
# 9743                   germany
# 9744                   germany
# 9745                   germany
# 9746            united kingdom
# 9747                    russia
# 9748                 australia
# 9749  united states of america
# 9750            united kingdom
# 9751                   germany
# 9752            united kingdom
# 9753                       NaN
#
# [9751 rows x 5 columns]

# %% [markdown]
# # Tabela curada manualmente

# %%
manual = pd.read_csv("df_manual.csv", index_col=[0])

# %%
manual.head(5)
# Out:
#                                                Journal  \
# 57   International journal of systematic and evolut...
# 198             Journal of microbiology (Seoul, Korea)
# 308                Systematic and applied microbiology
# 466  International journal of systematic and evolut...
# 544  International journal of systematic and evolut...
#
#                                          Article Title  Year  \
# 57   Pectobacterium punjabense sp. nov., isolated f...  2018
# 198  Taxonomic description and draft genome of Pseu...  2018
# 308  Bradyrhizobium algeriense sp. nov., a novel sp...  2018
# 466                    Listeria costaricensis sp. nov.  2018
# 544  Leptospira venezuelensis sp. nov., a new membe...  2018
#
#                                            Affiliation     Country
# 57   1​Department of Plant Pathology, Faculty of Ag...    pakistan
# 198  Wetland Research and Training Centre, Chilika ...       india
# 308  Laboratoire d'Ecologie Microbienne, Faculté de...     algeria
# 466  1​Centro de Investigación en Biotecnología, Es...  costa rica
# 544  1​Unidad de Estudios Genéticos y Forenses, Ins...   venezuela

# %%
sem_2019_sem_na = sem_2019.dropna(how="any")

# %%
completa = sem_2019_sem_na.append(manual)

# %%
completa
# Out:
#                                                 Journal  \
# 1     International journal of systematic and evolut...
# 2     International journal of systematic and evolut...
# 5     International journal of systematic and evolut...
# 6     International journal of systematic and evolut...
# 7     International journal of systematic and evolut...
# 8     International journal of systematic and evolut...
# 9     International journal of systematic and evolut...
# 10    International journal of systematic and evolut...
# 11    International journal of systematic and evolut...
# 12    International journal of systematic and evolut...
# 13    International journal of systematic and evolut...
# 14    International journal of systematic and evolut...
# 15    International journal of systematic and evolut...
# 16    International journal of systematic and evolut...
# 17    International journal of systematic and evolut...
# 18               Journal of microbiology (Seoul, Korea)
# 19    International journal of systematic and evolut...
# 20    International journal of systematic and evolut...
# 21    International journal of systematic and evolut...
# 22    International journal of systematic and evolut...
# 23    International journal of systematic and evolut...
# 24    International journal of systematic and evolut...
# 25    International journal of systematic and evolut...
# 26    International journal of systematic and evolut...
# 27    International journal of systematic and evolut...
# 28    International journal of systematic and evolut...
# 29    International journal of systematic and evolut...
# 30    International journal of systematic and evolut...
# 31    International journal of systematic and evolut...
# 32    International journal of systematic and evolut...
# ...                                                 ...
# 9437                Systematic and applied microbiology
# 9450  International journal of systematic and evolut...
# 9456  International journal of systematic and evolut...
# 9492  International journal of systematic and evolut...
# 9506  International journal of systematic and evolut...
# 9509  International journal of systematic and evolut...
# 9516             Applied microbiology and biotechnology
# 9528  International journal of systematic and evolut...
# 9529  International journal of systematic and evolut...
# 9531  International journal of systematic and evolut...
# 9540  International journal of systematic and evolut...
# 9541  International journal of systematic and evolut...
# 9555  International journal of systematic and evolut...
# 9557  International journal of systematic and evolut...
# 9558  International journal of systematic and evolut...
# 9566  International journal of systematic and evolut...
# 9569  International journal of systematic and evolut...
# 9584  International journal of systematic and evolut...
# 9635                   Journal of clinical microbiology
# 9641  International journal of systematic and evolut...
# 9644  International journal of systematic and evolut...
# 9651  International journal of systematic and evolut...
# 9660  International journal of systematic and evolut...
# 9674  International journal of systematic and evolut...
# 9686  International journal of systematic and evolut...
# 9691  International journal of systematic and evolut...
# 9692  International journal of systematic and evolut...
# 9696  International journal of systematic and evolut...
# 9717  International journal of systematic and evolut...
# 9753                   Journal of clinical microbiology
#
#                                           Article Title  Year  \
# 1     Leucothrix arctica sp. nov., isolated from Arc...  2018
# 2     Hyphobacterium indicum sp. nov., isolated from...  2018
# 5     Sphingopyxis lindanitolerans sp. nov. strain W...  2018
# 6     Mesosutterella multiformis gen. nov., sp. nov....  2018
# 7     Acinetobacter sichuanensis sp. nov., recovered...  2018
# 8     Enterobacter sichuanensis sp. nov., recovered ...  2018
# 9     Kribbella monticola sp. nov., a novel actinomy...  2018
# 10    Halomonas litopenaei sp. nov., a moderately ha...  2018
# 11    Alsobacter soli sp. nov., a novel bacterium is...  2018
# 12    Microbacterium halophytorum sp. nov., a novel ...  2018
# 13    Salinimonas sediminis sp. nov., a piezophilic ...  2018
# 14    Nocardioides houyundeii sp. nov., isolated fro...  2018
# 15    Clostridium composti sp. nov., a new anaerobic...  2018
# 16    Taxonomic status of Corynebacterium diphtheria...  2018
# 17    Flavobacterium sediminis sp. nov., a starch-de...  2018
# 18    Roseovarius tibetensis sp. nov., a halophilic ...  2018
# 19    Arthrobacter silvisoli sp. nov., isolated from...  2018
# 20    Alteromonas indica sp. nov., isolated from sur...  2018
# 21    Actinomyces tangfeifanii sp. nov., isolated fr...  2018
# 22    Reclassification of Eubacterium hallii as Anae...  2018
# 23    Litorivita pollutaquae gen. nov., sp. nov., a ...  2018
# 24    Prevotella rara sp. nov., isolated from human ...  2018
# 25    Jeotgalibacillus proteolyticus sp. nov., a pro...  2018
# 26    Paracoccus salipaludis sp. nov., isolated from...  2018
# 27    Minwuia thermotolerans gen. nov., sp. nov., a ...  2018
# 28    Microbispora soli sp. nov., isolated from soil...  2018
# 29    Lactococcus termiticola sp. nov., isolated fro...  2018
# 30    Flavobacterium riviphilum sp. nov., isolated f...  2018
# 31    Flavobacterium magnum sp. nov., Flavobacterium...  2018
# 32    Zobellella endophytica sp. nov., isolated from...  2018
# ...                                                 ...   ...
# 9437  Ruminococcus luti sp. nov., isolated from a hu...  2002
# 9450  Psychrobacter submarinus sp. nov. and Psychrob...  2002
# 9456  Taxonomic dissection of the Streptococcus bovi...  2002
# 9492  Oleiphilaceae fam. nov., to include Oleiphilus...  2002
# 9506  Mitsuokella jalaludinii sp. nov., from the rum...  2002
# 9509  Arthrobacter roseus sp. nov., a psychrophilic ...  2002
# 9516  Bacillus naphthovorans sp. nov. from oil-conta...  2002
# 9528  Stenotrophomonas acidaminiphila sp. nov., a st...  2002
# 9529  Saccharomonospora halophila sp. nov., a novel ...  2002
# 9531  Nocardiopsis halotolerans sp. nov., isolated f...  2002
# 9540  Reclassification of Eubacterium formicigeneran...  2002
# 9541  Paenibacillus chinjuensis sp. nov., a novel ex...  2002
# 9555  Pseudoalteromonas maricaloris sp. nov., isolat...  2002
# 9557  Pseudoalteromonas ruthenica sp. nov., isolated...  2002
# 9558  Pseudoalteromonas issachenkonii sp. nov., a ba...  2002
# 9566  Anaerobaculum mobile sp. nov., a novel anaerob...  2002
# 9569  Halomonas alimentaria sp. nov., isolated from ...  2002
# 9584  Jeotgalibacillus alimentarius gen. nov., sp. n...  2001
# 9635  Description of Mycobacterium heckeshornense sp...  2001
# 9641  Planomicrobium koreense gen. nov., sp. nov., a...  2001
# 9644  Sphingomonas aquatilis sp. nov., Sphingomonas ...  2001
# 9651  Hydrogenobacter subterraneus sp. nov., an extr...  2001
# 9660  Novel nitrogen-fixing acetic acid bacteria, Gl...  2001
# 9674  Comamonas nitrativorans sp. nov., a novel deni...  2001
# 9686  Halomonas marisflavae sp. nov., a halophilic b...  2001
# 9691  Bacillus jeotgali sp. nov., isolated from jeot...  2001
# 9692  Sporosarcina aquimarina sp. nov., a bacterium ...  2001
# 9696                       Shewanella japonica sp. nov.  2001
# 9717  Actinopolymorpha singaporensis gen. nov., sp. ...  2001
# 9753  Nocardia africana sp. nov., a new pathogen iso...  2001
#
#                                             Affiliation       Country
# 1     2​Freshwater Bioresources Research Bureau, Nak...   south korea
# 2     1​State Key Laboratory of Microbial Resources,...         china
# 5     1​Institute of Biochemistry and Biophysics, Po...        poland
# 6     1​Microbe Division/Japan Collection of Microor...         japan
# 7     1​Center of Infectious Diseases, West China Ho...         china
# 8     1​Center of Infectious Diseases, West China Ho...         china
# 9     1​Key Laboratory of Agriculture Biological Fun...         china
# 10    1​Fisheries College, Guangdong Ocean Universit...         china
# 11    1​Eco-Environmental Protection Research Instit...         china
# 12    1​Xinjiang Key Laboratory of Special Species C...         china
# 13    2​National Engineering Research Center for Oce...         china
# 14    1​Guangxi Key Laboratory of AIDS Prevention an...         china
# 15    1​ABS Research Support Center/Korean Collectio...   south korea
# 16    1​Institut Pasteur, Biodiversity and Epidemiol...        france
# 17    1​National Marine Biodiversity Institute of Ko...   south korea
# 18    State Key Laboratory of Lake Science and Envir...         china
# 19    1​School of Life Science, Northeast Agricultur...         china
# 20    College of Biological and Environmental Scienc...         china
# 21    1​State Key Laboratory of Infectious Disease P...         china
# 22    1​Laboratory of Microbiology, Wageningen Unive...   netherlands
# 23    Key Laboratory of the Ministry of Education fo...         china
# 24    1​Department of Microbiology and Virology, Pir...        russia
# 25    1​Key Laboratory of Coastal Biology and Utiliz...         china
# 26    1​Jiangsu Provincial Key Lab for Organic Solid...         china
# 27    1​College of Life Sciences, Zhejiang Sci-Tech ...         china
# 28    1​Department of Biology and Actinobacterial re...      thailand
# 29    1​Graduate School of Life and Environmental Sc...         japan
# 30    1​Department of Marine Biotechnology, National...        taiwan
# 31    1​Department of Public Health Sciences, Gradua...   south korea
# 32    1​State Key Laboratory of Tree Genetics and Br...         china
# ...                                                 ...           ...
# 9437  Department of Gastrointestinal Microbiology, G...       germany
# 9450  Pacific Institute of Bioorganic Chemistry, Far...        russia
# 9456                                 cpoyart@pasteur.fr        france
# 9492  Division of Microbiology, GBF-German Research ...       germany
# 9506  Institute of Bioscience, Universiti Putra Mala...      malaysia
# 9509  Centre for Cellular and Molecular Biology, Hyd...         india
# 9516  Environmental Engineering Research Centre, Div...     singapore
# 9528  Département de Biochimie-Microbiologie, Facult...  burkina faso
# 9529  Kuwait University, Department of Biological Sc...        kuwait
# 9531  Dept of Biological Sciences, Kuwait University...        kuwait
# 9540  Department of Gastrointestinal Microbiology, G...       germany
# 9541  Korea Research Institute of Bioscience and Bio...   south korea
# 9555  Pacific Institute of Bioorganic Chemistry of t...        russia
# 9557  Pacific Institute of Bioorganic Chemistry of t...        russia
# 9558  Pacific Institute of Bioorganic Chemistry of t...        russia
# 9566  Facultad de Química, Universidad de la Repúbli...       uruguay
# 9569  Korea Research Institute of Bioscience and Bio...   south korea
# 9584  Korea Research Institute of Bioscience and Bio...   south korea
# 9635  G.K.Skryabin Institute of Biochemistry and Phy...        russia
# 9641  Korea Research Institute of Bioscience and Bio...   south korea
# 9644  Korea Research Institute of Bioscience and Bio...   south korea
# 9651  Subground Animalcules Retrieval (SUGAR) Projec...         japan
# 9660  Centro de Investigación sobre Fijación de Nitr...        mexico
# 9674  Departamento de Microbiología, Facultad de Quí...       uruguay
# 9686  Korea Research Institute of Bioscience and Bio...   south korea
# 9691  Korea Research Institute of Biosciences and Bi...   south korea
# 9692  Korea Research Institute of Bioscience and Bio...   south korea
# 9696  Pacific Institute of Bioorganic Chemistry of t...        russia
# 9717  Microbial Collection and Screening Laboratory,...     singapore
# 9753  Department of Preventive Medicine and Public H...         sudan
#
# [9751 rows x 5 columns]

# %%
completa[completa["Country"].isna()]
# Out:
# Empty DataFrame
# Columns: [Journal, Article Title, Year, Affiliation, Country]
# Index: []

# %%
completa.to_csv("tabela_paises.csv")

# %%
completa["Article Title"].to_csv("titles_completa_countries.txt")

# %% [markdown]
# # Gráficos

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
completa["Country"].value_counts()
# Out:
# china                       2322
# south korea                 2133
# japan                        830
# germany                      595
# united states of america     456
# india                        444
# spain                        352
# russia                       314
# france                       271
# taiwan                       244
# united kingdom               216
# thailand                     171
# belgium                      160
# australia                     88
# portugal                      84
# austria                       76
# italy                         65
# brazil                        62
# czech republic                58
# denmark                       57
# netherlands                   55
# iran                          52
# canada                        51
# turkey                        50
# south africa                  44
# mexico                        35
# hungary                       34
# switzerland                   33
# algeria                       33
# greece                        32
#                             ...
# pakistan                      10
# morocco                        9
# saudi arabia                   8
# argentina                      8
# egypt                          8
# colombia                       8
# uruguay                        7
# chile                          6
# slovenia                       6
# vietnam                        5
# indonesia                      5
# iceland                        5
# kuwait                         4
# lithuania                      4
# new caledonia                  3
# bulgaria                       3
# romania                        3
# venezuela                      2
# croatia                        2
# burkina faso                   2
# peru                           1
# costa rica                     1
# dominican republic             1
# bolivia                        1
# kenya                          1
# puerto rico                    1
# sudan                          1
# slovak republic                1
# cameroon                       1
# benin                          1
# Name: Country, Length: 71, dtype: int64

# %%
#Todos
all_papers_by_year = pd.DataFrame(completa["Year"].value_counts().reset_index())
all_papers_by_year.columns = ['year', 'count']
all_papers_by_year_sorted = all_papers_by_year.sort_values(by="year").reset_index(drop=True)
all_papers_by_year_sorted['cum_sum'] = all_papers_by_year_sorted["count"].cumsum()
all_papers_by_year_sorted
# Out:
#     year  count  cum_sum
# 0   2001    179      179
# 1   2002    234      413
# 2   2003    269      682
# 3   2004    330     1012
# 4   2005    376     1388
# 5   2006    416     1804
# 6   2007    502     2306
# 7   2008    486     2792
# 8   2009    529     3321
# 9   2010    534     3855
# 10  2011    534     4389
# 11  2012    560     4949
# 12  2013    853     5802
# 13  2014    757     6559
# 14  2015    903     7462
# 15  2016    775     8237
# 16  2017    867     9104
# 17  2018    647     9751

# %%
#china
china = completa[completa["Country"] == "china"]
china_papers_by_year = pd.DataFrame(china["Year"].value_counts().reset_index())
china_papers_by_year.columns = ['year', 'count']
china_papers_by_year_sorted = china_papers_by_year.sort_values(by="year").reset_index(drop=True)
china_papers_by_year_sorted['cum_sum'] = china_papers_by_year_sorted["count"].cumsum()
china_papers_by_year_sorted["proportion"] = china_papers_by_year_sorted["count"]/all_papers_by_year_sorted["count"]
china_papers_by_year_sorted
# Out:
#     year  count  cum_sum  proportion
# 0   2001      6        6    0.033520
# 1   2002     14       20    0.059829
# 2   2003     14       34    0.052045
# 3   2004     22       56    0.066667
# 4   2005     41       97    0.109043
# 5   2006     33      130    0.079327
# 6   2007     50      180    0.099602
# 7   2008     78      258    0.160494
# 8   2009    134      392    0.253308
# 9   2010     95      487    0.177903
# 10  2011    133      620    0.249064
# 11  2012    141      761    0.251786
# 12  2013    200      961    0.234467
# 13  2014    238     1199    0.314399
# 14  2015    330     1529    0.365449
# 15  2016    267     1796    0.344516
# 16  2017    280     2076    0.322953
# 17  2018    246     2322    0.380216

# %%
#korea
korea = completa[completa["Country"] == "south korea"]
korea_papers_by_year = pd.DataFrame(korea["Year"].value_counts().reset_index())
korea_papers_by_year.columns = ['year', 'count']
korea_papers_by_year_sorted = korea_papers_by_year.sort_values(by="year").reset_index(drop=True)
korea_papers_by_year_sorted['cum_sum'] = korea_papers_by_year_sorted["count"].cumsum()
korea_papers_by_year_sorted["proportion"] = korea_papers_by_year_sorted["count"]/all_papers_by_year_sorted["count"]
korea_papers_by_year_sorted
# Out:
#     year  count  cum_sum  proportion
# 0   2001      9        9    0.050279
# 1   2002     12       21    0.051282
# 2   2003     19       40    0.070632
# 3   2004     35       75    0.106061
# 4   2005     61      136    0.162234
# 5   2006     96      232    0.230769
# 6   2007    140      372    0.278884
# 7   2008    127      499    0.261317
# 8   2009    105      604    0.198488
# 9   2010    121      725    0.226592
# 10  2011    110      835    0.205993
# 11  2012    118      953    0.210714
# 12  2013    196     1149    0.229777
# 13  2014    182     1331    0.240423
# 14  2015    207     1538    0.229236
# 15  2016    171     1709    0.220645
# 16  2017    240     1949    0.276817
# 17  2018    184     2133    0.284389

# %%
japan = completa[completa["Country"] == "japan"]
japan_papers_by_year = pd.DataFrame(japan["Year"].value_counts().reset_index())
japan_papers_by_year.columns = ['year', 'count']
japan_papers_by_year_sorted = japan_papers_by_year.sort_values(by="year").reset_index(drop=True)
japan_papers_by_year_sorted['cum_sum'] = japan_papers_by_year_sorted["count"].cumsum()
japan_papers_by_year_sorted["proportion"] = japan_papers_by_year_sorted["count"]/all_papers_by_year_sorted["count"]
japan_papers_by_year_sorted
# Out:
#     year  count  cum_sum  proportion
# 0   2001     16       16    0.089385
# 1   2002     28       44    0.119658
# 2   2003     31       75    0.115242
# 3   2004     40      115    0.121212
# 4   2005     42      157    0.111702
# 5   2006     47      204    0.112981
# 6   2007     83      287    0.165339
# 7   2008     57      344    0.117284
# 8   2009     55      399    0.103970
# 9   2010     55      454    0.102996
# 10  2011     57      511    0.106742
# 11  2012     47      558    0.083929
# 12  2013     69      627    0.080891
# 13  2014     63      690    0.083223
# 14  2015     45      735    0.049834
# 15  2016     38      773    0.049032
# 16  2017     35      808    0.040369
# 17  2018     22      830    0.034003

# %%
germany = completa[completa["Country"] == "germany"]
germany_papers_by_year = pd.DataFrame(germany["Year"].value_counts().reset_index())
germany_papers_by_year.columns = ['year', 'count']
germany_papers_by_year_sorted = germany_papers_by_year.sort_values(by="year").reset_index(drop=True)
germany_papers_by_year_sorted['cum_sum'] = germany_papers_by_year_sorted["count"].cumsum()
germany_papers_by_year_sorted["proportion"] = germany_papers_by_year_sorted["count"]/all_papers_by_year_sorted["count"]
germany_papers_by_year_sorted
# Out:
#     year  count  cum_sum  proportion
# 0   2001     25       25    0.139665
# 1   2002     33       58    0.141026
# 2   2003     26       84    0.096654
# 3   2004     27      111    0.081818
# 4   2005     21      132    0.055851
# 5   2006     37      169    0.088942
# 6   2007     35      204    0.069721
# 7   2008     30      234    0.061728
# 8   2009     33      267    0.062382
# 9   2010     39      306    0.073034
# 10  2011     28      334    0.052434
# 11  2012     31      365    0.055357
# 12  2013     61      426    0.071512
# 13  2014     25      451    0.033025
# 14  2015     47      498    0.052049
# 15  2016     39      537    0.050323
# 16  2017     33      570    0.038062
# 17  2018     25      595    0.038640

# %%
#usa
usa = completa[completa["Country"] == "united states of america"]
usa_papers_by_year = pd.DataFrame(usa["Year"].value_counts().reset_index())
usa_papers_by_year.columns = ['year', 'count']
usa_papers_by_year_sorted = usa_papers_by_year.sort_values(by="year").reset_index(drop=True)
usa_papers_by_year_sorted['cum_sum'] = usa_papers_by_year_sorted["count"].cumsum()
usa_papers_by_year_sorted["proportion"] = usa_papers_by_year_sorted["count"]/all_papers_by_year_sorted["count"]
usa_papers_by_year_sorted
# Out:
#     year  count  cum_sum  proportion
# 0   2001     21       21    0.117318
# 1   2002     20       41    0.085470
# 2   2003     26       67    0.096654
# 3   2004     34      101    0.103030
# 4   2005     27      128    0.071809
# 5   2006     36      164    0.086538
# 6   2007     30      194    0.059761
# 7   2008     19      213    0.039095
# 8   2009     22      235    0.041588
# 9   2010     22      257    0.041199
# 10  2011     18      275    0.033708
# 11  2012     28      303    0.050000
# 12  2013     36      339    0.042204
# 13  2014     20      359    0.026420
# 14  2015     29      388    0.032115
# 15  2016     28      416    0.036129
# 16  2017     28      444    0.032295
# 17  2018     12      456    0.018547

# %%
#brazil
brazil = completa[completa["Country"] == "brazil"]
brazil_papers_by_year = pd.DataFrame(brazil["Year"].value_counts().reset_index())
brazil_papers_by_year.columns = ['year', 'count']
new_rows = pd.DataFrame([[2007, 0], [2008, 0], [2009, 0]], columns=["year", "count"])
brazil_papers_by_year = brazil_papers_by_year.append(new_rows)
brazil_papers_by_year_sorted = brazil_papers_by_year.sort_values(by="year").reset_index(drop=True)
brazil_papers_by_year_sorted['cum_sum'] = brazil_papers_by_year_sorted["count"].cumsum()
brazil_papers_by_year_sorted["proportion"] = brazil_papers_by_year_sorted["count"]/all_papers_by_year_sorted["count"]
brazil_papers_by_year_sorted
# Out:
#     year  count  cum_sum  proportion
# 0   2001      1        1    0.005587
# 1   2002      1        2    0.004274
# 2   2003      2        4    0.007435
# 3   2004      2        6    0.006061
# 4   2005      1        7    0.002660
# 5   2006      3       10    0.007212
# 6   2007      0       10    0.000000
# 7   2008      1       11    0.002058
# 8   2008      0       11    0.000000
# 9   2009      0       11    0.000000
# 10  2010      2       13    0.003745
# 11  2011      6       19    0.010714
# 12  2012      1       20    0.001172
# 13  2013      4       24    0.005284
# 14  2014      7       31    0.007752
# 15  2015      7       38    0.009032
# 16  2016      6       44    0.006920
# 17  2017     12       56    0.018547
# 18  2018      6       62         NaN

# %%
#Proportion of number of papers by year considering first author country affiliation

fig, ax = plt.subplots(figsize=(12,8))

data_set = [china_papers_by_year_sorted, korea_papers_by_year_sorted, japan_papers_by_year_sorted, germany_papers_by_year_sorted, usa_papers_by_year_sorted]
country_set = ["China", "South Korea", "Japan", "Germany", "USA"]
color_set = sns.color_palette("husl")
y_set = [0.84, 0.66, 0.18, 0.20, 0.15]


for d, c, i, y_pos in zip(data_set, country_set, color_set, y_set):
    sns.pointplot(x="year", y="proportion", data = d, color = i)
    fig.text(x = 0.91, y = y_pos, s = c, weight = "bold", color = i)

ax.set_ylim([0,0.4])
ax.set_ylabel("Relative contribution")
ax.set_xlabel("Year")
    
plt.show()

# %%
#Cumulative number of papers by year considering first author country affiliation

fig, ax = plt.subplots(figsize=(12,8))

data_set = [china_papers_by_year_sorted, korea_papers_by_year_sorted, japan_papers_by_year_sorted, germany_papers_by_year_sorted, usa_papers_by_year_sorted]
country_set = ["China", "South Korea", "Japan", "Germany", "USA"]
color_set = sns.color_palette("husl")
y_set = [0.82, 0.76, 0.37, 0.30, 0.26]


for d, c, i, y_pos in zip(data_set, country_set, color_set, y_set):
    sns.pointplot(x="year", y="cum_sum", data = d, color = i)
    fig.text(x = 0.91, y = y_pos, s = c, weight = "bold", color = i)


ax.set_ylim([0,2500])
ax.set_ylabel("Cumulative frequency of papers")
ax.set_xlabel("Year")

    
plt.show()
